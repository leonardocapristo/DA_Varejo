# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.12.4

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %% [markdown]
# ## Carregando os Dados

# %%
# Carrega o dataset
df_dsa = pd.read_csv("D:/Projetos/DA_Varejo/dados/dataset.csv")

# %%
# Shape (mostra o tanto de linhas x colunas)
df_dsa.shape
# Out:
# (9700, 11)

# %%
# Amostra dos dados (mostra 5 primeiras linhas do dataframe)
df_dsa.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# 4      22.3680

# %%
# Amostra dos dados (mostra 5 ultimas linhas do df)
df_dsa.tail()
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 9695  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9696  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9697  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9698  CA-2017-105291  30/10/2017   SP-20920     Consumer  United States
# 9699  CA-2018-147032  31/07/2018   LB-16795  Home Office  United States
#
#                Cidade      Estado       ID_Produto        Categoria  \
# 9695        Inglewood  California  OFF-PA-10004569  Office Supplies
# 9696        Inglewood  California  OFF-AP-10000027  Office Supplies
# 9697        Inglewood  California  TEC-PH-10000675       Technology
# 9698  San Luis Obispo  California  OFF-FA-10003059  Office Supplies
# 9699       Wilmington    Delaware  OFF-PA-10003256  Office Supplies
#
#      SubCategoria  Valor_Venda
# 9695        Paper       22.830
# 9696   Appliances       54.320
# 9697       Phones      196.776
# 9698    Fasteners        3.620
# 9699        Paper       11.540

# %% [markdown]
# ## Análise Exploratória

# %%
# Colunas do conjunto de dados
df_dsa.columns
# Out:
# Index(['ID_Pedido', 'Data_Pedido', 'ID_Cliente', 'Segmento', 'Pais', 'Cidade',
#        'Estado', 'ID_Produto', 'Categoria', 'SubCategoria', 'Valor_Venda'],
#       dtype='object')

# %%
# Reorganizando a visualização colunas (não está alterando o df original)
pd.DataFrame(df_dsa, columns = ['Data_Pedido', 'ID_Pedido', 'ID_Cliente', 'Segmento', 'Pais', 'Cidade',
       'Estado', 'ID_Produto', 'Categoria', 'SubCategoria', 'Valor_Venda'])
# Out:
#      Data_Pedido       ID_Pedido ID_Cliente     Segmento           Pais  \
# 0     08/11/2017  CA-2017-152156   CG-12520     Consumer  United States
# 1     08/11/2017  CA-2017-152156   CG-12520     Consumer  United States
# 2     12/06/2017  CA-2017-138688   DV-13045    Corporate  United States
# 3     11/10/2016  US-2016-108966   SO-20335     Consumer  United States
# 4     11/10/2016  US-2016-108966   SO-20335     Consumer  United States
# ...          ...             ...        ...          ...            ...
# 9695  15/12/2018  CA-2018-154116   KM-16660     Consumer  United States
# 9696  15/12/2018  CA-2018-154116   KM-16660     Consumer  United States
# 9697  15/12/2018  CA-2018-154116   KM-16660     Consumer  United States
# 9698  30/10/2017  CA-2017-105291   SP-20920     Consumer  United States
# 9699  31/07/2018  CA-2018-147032   LB-16795  Home Office  United States
#
#                Cidade      Estado       ID_Produto        Categoria  \
# 0           Henderson    Kentucky  FUR-BO-10001798        Furniture
# 1           Henderson    Kentucky  FUR-CH-10000454        Furniture
# 2         Los Angeles  California  OFF-LA-10000240  Office Supplies
# 3     Fort Lauderdale     Florida  FUR-TA-10000577        Furniture
# 4     Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies
# ...               ...         ...              ...              ...
# 9695        Inglewood  California  OFF-PA-10004569  Office Supplies
# 9696        Inglewood  California  OFF-AP-10000027  Office Supplies
# 9697        Inglewood  California  TEC-PH-10000675       Technology
# 9698  San Luis Obispo  California  OFF-FA-10003059  Office Supplies
# 9699       Wilmington    Delaware  OFF-PA-10003256  Office Supplies
#
#      SubCategoria  Valor_Venda
# 0       Bookcases     261.9600
# 1          Chairs     731.9400
# 2          Labels      14.6200
# 3          Tables     957.5775
# 4         Storage      22.3680
# ...           ...          ...
# 9695        Paper      22.8300
# 9696   Appliances      54.3200
# 9697       Phones     196.7760
# 9698    Fasteners       3.6200
# 9699        Paper      11.5400
#
# [9700 rows x 11 columns]

# %%
#alterando de fato a ordem das colunas do df
df_dsa = pd.DataFrame(df_dsa, columns = ['Data_Pedido', 'ID_Pedido', 'ID_Cliente', 'Segmento', 'Pais', 'Cidade',
       'Estado', 'ID_Produto', 'Categoria', 'SubCategoria', 'Valor_Venda'])

# %%
df_dsa.head()
# Out:
#   Data_Pedido       ID_Pedido ID_Cliente   Segmento           Pais  \
# 0  08/11/2017  CA-2017-152156   CG-12520   Consumer  United States
# 1  08/11/2017  CA-2017-152156   CG-12520   Consumer  United States
# 2  12/06/2017  CA-2017-138688   DV-13045  Corporate  United States
# 3  11/10/2016  US-2016-108966   SO-20335   Consumer  United States
# 4  11/10/2016  US-2016-108966   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# 4      22.3680

# %%
# Verificando o tipo de dado de cada coluna
df_dsa.dtypes
# Out:
# Data_Pedido      object
# ID_Pedido        object
# ID_Cliente       object
# Segmento         object
# Pais             object
# Cidade           object
# Estado           object
# ID_Produto       object
# Categoria        object
# SubCategoria     object
# Valor_Venda     float64
# dtype: object

# %%
# Resumo estatístico da coluna com o valor de venda
df_dsa['Valor_Venda'].describe()
# Out:
# count     9700.000000
# mean       230.469892
# std        627.504252
# min          0.444000
# 25%         17.248000
# 50%         54.272000
# 75%        209.932500
# max      22638.480000
# Name: Valor_Venda, dtype: float64

# %%
# Verificando se há registros duplicados
df_dsa[df_dsa.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Data_Pedido, ID_Pedido, ID_Cliente, Segmento, Pais, Cidade, Estado, ID_Produto, Categoria, SubCategoria, Valor_Venda]
# Index: []

# %%
# Verificando de há valores ausentes
df_dsa.isnull().sum()
# Out:
# Data_Pedido     0
# ID_Pedido       0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Cidade          0
# Estado          0
# ID_Produto      0
# Categoria       0
# SubCategoria    0
# Valor_Venda     0
# dtype: int64

# %%
df_dsa.head()
# Out:
#   Data_Pedido       ID_Pedido ID_Cliente   Segmento           Pais  \
# 0  08/11/2017  CA-2017-152156   CG-12520   Consumer  United States
# 1  08/11/2017  CA-2017-152156   CG-12520   Consumer  United States
# 2  12/06/2017  CA-2017-138688   DV-13045  Corporate  United States
# 3  11/10/2016  US-2016-108966   SO-20335   Consumer  United States
# 4  11/10/2016  US-2016-108966   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# 4      22.3680

# %% [markdown]
# ## Pergunta de Negócio 1:
#
# ### Qual Cidade com Maior Valor de Venda de Produtos da Categoria 'Office Supplies'?

# %%
# Descrevendo os dados não numéricos (mostra os dados que não sao números, a maioria é string)
# count = O número de campos presenstes não nulas (não NaN) na coluna.
# unique = O número de valores únicos(categorias) na coluna mas que podem se repetir nas linhas.
#top = O valor mais frequente (modo) na coluna.
#freq = Está atrelado ao top A frequência do valor mais comum (quantas vezes o valor mais frequente aparece).

df_dsa.describe(include = object)
# Out:
#        Data_Pedido       ID_Pedido ID_Cliente  Segmento           Pais  \
# count         9700            9700       9700      9700           9700
# unique        1226            4874        793         3              1
# top     05/09/2017  CA-2018-100111   WB-21850  Consumer  United States
# freq            38              14         35      5039           9700
#
#                Cidade      Estado       ID_Produto        Categoria  \
# count            9700        9700             9700             9700
# unique            528          49             1861                3
# top     New York City  California  OFF-PA-10001970  Office Supplies
# freq              888        1929               19             5851
#
#        SubCategoria
# count          9700
# unique           17
# top         Binders
# freq           1470

# %%
#Verificando valores unicos da coluna categoria
df_dsa["Categoria"].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
# Primeiro filtramos o dataframe com os registros da categoria que desejamos
df_dsa_p1 = df_dsa[df_dsa['Categoria'] == 'Office Supplies']

# %%
df_dsa_p1
# Out:
#      Data_Pedido       ID_Pedido ID_Cliente     Segmento           Pais  \
# 2     12/06/2017  CA-2017-138688   DV-13045    Corporate  United States
# 4     11/10/2016  US-2016-108966   SO-20335     Consumer  United States
# 6     09/06/2015  CA-2015-115812   BH-11710     Consumer  United States
# 8     09/06/2015  CA-2015-115812   BH-11710     Consumer  United States
# 9     09/06/2015  CA-2015-115812   BH-11710     Consumer  United States
# ...          ...             ...        ...          ...            ...
# 9693  10/06/2015  CA-2015-144281   HK-14890    Corporate  United States
# 9695  15/12/2018  CA-2018-154116   KM-16660     Consumer  United States
# 9696  15/12/2018  CA-2018-154116   KM-16660     Consumer  United States
# 9698  30/10/2017  CA-2017-105291   SP-20920     Consumer  United States
# 9699  31/07/2018  CA-2018-147032   LB-16795  Home Office  United States
#
#                Cidade      Estado       ID_Produto        Categoria  \
# 2         Los Angeles  California  OFF-LA-10000240  Office Supplies
# 4     Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies
# 6         Los Angeles  California  OFF-AR-10002833  Office Supplies
# 8         Los Angeles  California  OFF-BI-10003910  Office Supplies
# 9         Los Angeles  California  OFF-AP-10002892  Office Supplies
# ...               ...         ...              ...              ...
# 9693          Detroit    Michigan  OFF-LA-10003930  Office Supplies
# 9695        Inglewood  California  OFF-PA-10004569  Office Supplies
# 9696        Inglewood  California  OFF-AP-10000027  Office Supplies
# 9698  San Luis Obispo  California  OFF-FA-10003059  Office Supplies
# 9699       Wilmington    Delaware  OFF-PA-10003256  Office Supplies
#
#      SubCategoria  Valor_Venda
# 2          Labels       14.620
# 4         Storage       22.368
# 6             Art        7.280
# 8         Binders       18.504
# 9      Appliances      114.900
# ...           ...          ...
# 9693       Labels      491.550
# 9695        Paper       22.830
# 9696   Appliances       54.320
# 9698    Fasteners        3.620
# 9699        Paper       11.540
#
# [5851 rows x 11 columns]

# %%
# Em seguida agrupamos por cidade e calculamos o total de valor_venda
df_dsa_p1_total = df_dsa_p1.groupby('Cidade')['Valor_Venda'].sum()

# %%
df_dsa_p1
# Out:
#      Data_Pedido       ID_Pedido ID_Cliente     Segmento           Pais  \
# 2     12/06/2017  CA-2017-138688   DV-13045    Corporate  United States
# 4     11/10/2016  US-2016-108966   SO-20335     Consumer  United States
# 6     09/06/2015  CA-2015-115812   BH-11710     Consumer  United States
# 8     09/06/2015  CA-2015-115812   BH-11710     Consumer  United States
# 9     09/06/2015  CA-2015-115812   BH-11710     Consumer  United States
# ...          ...             ...        ...          ...            ...
# 9693  10/06/2015  CA-2015-144281   HK-14890    Corporate  United States
# 9695  15/12/2018  CA-2018-154116   KM-16660     Consumer  United States
# 9696  15/12/2018  CA-2018-154116   KM-16660     Consumer  United States
# 9698  30/10/2017  CA-2017-105291   SP-20920     Consumer  United States
# 9699  31/07/2018  CA-2018-147032   LB-16795  Home Office  United States
#
#                Cidade      Estado       ID_Produto        Categoria  \
# 2         Los Angeles  California  OFF-LA-10000240  Office Supplies
# 4     Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies
# 6         Los Angeles  California  OFF-AR-10002833  Office Supplies
# 8         Los Angeles  California  OFF-BI-10003910  Office Supplies
# 9         Los Angeles  California  OFF-AP-10002892  Office Supplies
# ...               ...         ...              ...              ...
# 9693          Detroit    Michigan  OFF-LA-10003930  Office Supplies
# 9695        Inglewood  California  OFF-PA-10004569  Office Supplies
# 9696        Inglewood  California  OFF-AP-10000027  Office Supplies
# 9698  San Luis Obispo  California  OFF-FA-10003059  Office Supplies
# 9699       Wilmington    Delaware  OFF-PA-10003256  Office Supplies
#
#      SubCategoria  Valor_Venda
# 2          Labels       14.620
# 4         Storage       22.368
# 6             Art        7.280
# 8         Binders       18.504
# 9      Appliances      114.900
# ...           ...          ...
# 9693       Labels      491.550
# 9695        Paper       22.830
# 9696   Appliances       54.320
# 9698    Fasteners        3.620
# 9699        Paper       11.540
#
# [5851 rows x 11 columns]

# %%
# Então encontramos a cidade com maior valor de venda
cidade_maior_venda = df_dsa_p1_total.idxmax()
print("Cidade com maior valor de venda para 'Office Supplies':", cidade_maior_venda)
# Out:
# Cidade com maior valor de venda para 'Office Supplies': New York City

# %%
# Para conferir o resultado
df_dsa_p1_total.sort_values(ascending = False)
# Out:
# Cidade
# New York City    68362.814
# Los Angeles      47098.100
# San Francisco    41771.198
# Seattle          34856.878
# Philadelphia     29313.687
#                    ...
# Ormond Beach         2.808
# Pensacola            2.214
# Jupiter              2.064
# Elyria               1.824
# Abilene              1.392
# Name: Valor_Venda, Length: 480, dtype: float64

# %% [markdown]
# ## Pergunta de Negócio 2:
#
# ### Qual o Total de Vendas Por Data do Pedido?
#
# Demonstre o resultado através de um gráfico de barras.

# %%
df_dsa_p2 = df_dsa.groupby('Data_Pedido')['Valor_Venda'].sum()

# %%
# Calculamos o total de vendas para cada data de pedido
df_dsa_p2 = df_dsa.groupby('Data_Pedido')['Valor_Venda'].sum()

# %%
df_dsa_p2.head()

# %% [markdown]
# Obs: Estamos aqui tratando data de pedido como variável categórica e não como série temporal. Se a pergunta fosse "ao longo do tempo" essa resposta não seria a ideal.

# %%
# Plot
plt.figure(figsize = (20, 6))
df_dsa_p2.plot(x = 'Data_Pedido', y = 'Valor_Venda', color = 'green')
plt.title('Total de Vendas Por Data do Pedido')
plt.show()

# %% [markdown]
# ## Pergunta de Negócio 3:
#
# ### Qual o Total de Vendas por Estado?
#
# Demonstre o resultado através de um gráfico de barras.

# %%
# Agrupamos por estado e calculamos o total de vendas
df_dsa_p3 = df_dsa.groupby('Estado')['Valor_Venda'].sum().reset_index()

# %%
# Plot
plt.figure(figsize = (16, 6))
sns.barplot(data = df_dsa_p3, 
            y = 'Valor_Venda', 
            x = 'Estado').set(title = 'Vendas Por Estado')
plt.xticks(rotation = 80)
plt.show()

# %% [markdown]
# ## Pergunta de Negócio 4:
#
# ### Quais São as 10 Cidades com Maior Total de Vendas?
#
# Demonstre o resultado através de um gráfico de barras.

# %%
# Agrupamos por cidade, calculamos o total de vendas e ordenamos listando somente os 10 primeiros registros
df_dsa_p4 = df_dsa.groupby('Cidade')['Valor_Venda'].sum().reset_index().sort_values(by = 'Valor_Venda',
                                                                                    ascending = False).head(10)

# %%
df_dsa_p4.head(10)

# %%
# Plot
plt.figure(figsize = (16, 6))
sns.set_palette('coolwarm')
sns.barplot(data = df_dsa_p4, 
            y = 'Valor_Venda', 
            x = 'Cidade').set(title = 'As 10 Cidades com Maior Total de Vendas')
plt.show()

# %% [markdown]
# ## Pergunta de Negócio 5:
#
# ### Qual Segmento Teve o Maior Total de Vendas?
#
# Demonstre o resultado através de um gráfico de pizza.

# %%
# Agrupamos por segmento e calculamos o total de vendas
df_dsa_p5 = df_dsa.groupby('Segmento')['Valor_Venda'].sum().reset_index().sort_values(by = 'Valor_Venda',
                                                                                      ascending = False)

# %%
df_dsa_p5.head()

# %%
# Função para converter os dados em valor absoluto
def autopct_format(values): 
    def my_format(pct): 
        total = sum(values) 
        val = int(round(pct * total / 100.0))
        return ' $ {v:d}'.format(v = val)
    return my_format

# %%
# Plot

# Tamanho da figura
plt.figure(figsize = (16, 6))

# Gráfico de pizza
plt.pie(df_dsa_p5['Valor_Venda'], 
        labels = df_dsa_p5['Segmento'],
        autopct = autopct_format(df_dsa_p5['Valor_Venda']),
        startangle = 90)

# Limpa o círculo central
centre_circle = plt.Circle((0, 0), 0.82, fc = 'white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Labels e anotações
plt.annotate(text = 'Total de Vendas: ' + '$ ' + str(int(sum(df_dsa_p5['Valor_Venda']))), xy = (-0.25, 0))
plt.title('Total de Vendas Por Segmento')
plt.show()

# %% [markdown]
# ## Pergunta de Negócio 6 (Desafio Nível Baby):
#
# ### Qual o Total de Vendas Por Segmento e Por Ano?

# %%
df_dsa.head()

# %%
# Convertemos a coluna de data para o tipo datetime para obter o formato adequado
df_dsa['Data_Pedido'] = pd.to_datetime(df_dsa['Data_Pedido'], dayfirst = True)

# %%
df_dsa.dtypes

# %%
# Extraímos o ano criando nova variável
df_dsa['Ano'] = df_dsa['Data_Pedido'].dt.year

# %%
df_dsa.head()

# %%
# Total de vendas por segmento e por ano
df_dsa_p6 = df_dsa.groupby(['Ano', 'Segmento'])['Valor_Venda'].sum()

# %%
df_dsa_p6

# %% [markdown]
# ## Pergunta de Negócio 7 (Desafio Nível Júnior):
#
# Os gestores da empresa estão considerando conceder diferentes faixas de descontos e gostariam de fazer uma simulação com base na regra abaixo:
#
# - Se o Valor_Venda for maior que 1000 recebe 15% de desconto.
# - Se o Valor_Venda for menor que 1000 recebe 10% de desconto.
#
# ### Quantas Vendas Receberiam 15% de Desconto?

# %%
# Cria uma nova coluna de acordo com a regra definida acima
df_dsa['Desconto'] = np.where(df_dsa['Valor_Venda'] > 1000, 0.15, 0.10)

# %%
df_dsa.head()

# %%
# Total por cada valor da variável
df_dsa['Desconto'].value_counts()

# %%
print('No Total 457 Vendas Receberiam Desconto de 15%.')

# %% [markdown]
# ## Pergunta de Negócio 8 (Desafio Nível Master):
#
# ### Considere Que a Empresa Decida Conceder o Desconto de 15% do Item Anterior. Qual Seria a Média do Valor de Venda Antes e Depois do Desconto?

# %%
# Criamos uma coluna calculando o valor de venda menos o desconto
df_dsa['Valor_Venda_Desconto'] = df_dsa['Valor_Venda'] - (df_dsa['Valor_Venda'] * df_dsa['Desconto'])

# %%
df_dsa.head()

# %%
# Filtrando as vendas antes do desconto de 15%
df_dsa_p8_vendas_antes_desconto = df_dsa.loc[df_dsa['Desconto'] == 0.15, 'Valor_Venda']

# %%
# Filtrando as vendas depois do desconto de 15%
df_dsa_p8_vendas_depois_desconto = df_dsa.loc[df_dsa['Desconto'] == 0.15, 'Valor_Venda_Desconto']

# %%
# Calcula a média das vendas antes do desconto de 15%
media_vendas_antes_desconto = df_dsa_p8_vendas_antes_desconto.mean()

# %%
# Calcula a média das vendas depois do desconto de 15%
media_vendas_depois_desconto = df_dsa_p8_vendas_depois_desconto.mean()

# %%
print("Média das vendas antes do desconto de 15%:", round(media_vendas_antes_desconto, 2))

# %%
print("Média das vendas depois do desconto de 15%:", round(media_vendas_depois_desconto, 2))

# %% [markdown]
# ## Pergunta de Negócio 9 (Desafio Nível Master Ninja):
#
# ### Qual o Média de Vendas Por Segmento, Por Ano e Por Mês?
#
# Demonstre o resultado através de gráfico de linha.

# %%
# Extraímos o mês e gravamos em uma nova variável
df_dsa['Mes'] = df_dsa['Data_Pedido'].dt.month

# %%
df_dsa.head()

# %%
# Agrupamos por ano, mês e segmento e calculamos estatísticas de agregação
df_dsa_p9 = df_dsa.groupby(['Ano', 'Mes', 'Segmento'])['Valor_Venda'].agg([np.sum, np.mean, np.median])

# %%
df_dsa_p9

# %%
# Vamos extrair os níveis
anos = df_dsa_p9.index.get_level_values(0)
meses = df_dsa_p9.index.get_level_values(1)
segmentos = df_dsa_p9.index.get_level_values(2)

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.relplot.html

# %%
# Plot
plt.figure(figsize = (12, 6))
sns.set()
fig1 = sns.relplot(kind = 'line',
                   data = df_dsa_p9, 
                   y = 'mean', 
                   x = meses,
                   hue = segmentos, 
                   col = anos,
                   col_wrap = 4)
plt.show()

# %% [markdown]
# ## Pergunta de Negócio 10 (Desafio Nível Master Ninja das Galáxias):
#
# ### Qual o Total de Vendas Por Categoria e SubCategoria, Considerando Somente as Top 12 SubCategorias?
#
# Demonstre tudo através de um único gráfico.

# %%
df_dsa.head()

# %%
# Agrupamos por categoria e subcategoria e calculamos a soma somente para variáveus numéricas
df_dsa_p10 = df_dsa.groupby(['Categoria',
                             'SubCategoria']).sum(numeric_only = True).sort_values('Valor_Venda',
                                                                                   ascending = False).head(12)

# %%
# Convertemos a coluna Valor_Venda em número inteiro e classificamos por categoria
df_dsa_p10 = df_dsa_p10[['Valor_Venda']].astype(int).sort_values(by = 'Categoria').reset_index()

# %% [markdown]
# Obs: Classificar o item acima por categoria é importante para preencher o gráfico com as subcategorias para cada categoria de forma ordenada.

# %%
# Dataframe com categorias e subcategorias
df_dsa_p10

# %%
# Criamos outro dataframe somente com os totais por categoria
df_dsa_p10_cat = df_dsa_p10.groupby('Categoria').sum(numeric_only = True).reset_index()

# %%
# Dataframe com categorias 
df_dsa_p10_cat

# %%
# Listas de cores para categorias
cores_categorias = ['#5d00de',
                    '#0ee84f',
                    '#e80e27']

# %%
# Listas de cores para subcategorias
cores_subcategorias = ['#aa8cd4',
                       '#aa8cd5',
                       '#aa8cd6',
                       '#aa8cd7',
                       '#26c957',
                       '#26c958',
                       '#26c959',
                       '#26c960',
                       '#e65e65',
                       '#e65e66',
                       '#e65e67',
                       '#e65e68']

# %%
# Plot

# Tamanho da figura
fig, ax = plt.subplots(figsize = (18,12))

# Gráfico das categorias
p1 = ax.pie(df_dsa_p10_cat['Valor_Venda'], 
            radius = 1,
            labels = df_dsa_p10_cat['Categoria'],
            wedgeprops = dict(edgecolor = 'white'),
            colors = cores_categorias)

# Gráfico das subcategorias
p2 = ax.pie(df_dsa_p10['Valor_Venda'],
            radius = 0.9,
            labels = df_dsa_p10['SubCategoria'],
            autopct = autopct_format(df_dsa_p10['Valor_Venda']),
            colors = cores_subcategorias, 
            labeldistance = 0.7,
            wedgeprops = dict(edgecolor = 'white'), 
            pctdistance = 0.53,
            rotatelabels = True)

# Limpa o centro do círculo
centre_circle = plt.Circle((0, 0), 0.6, fc = 'white')

# Labels e anotações
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.annotate(text = 'Total de Vendas: ' + '$ ' + str(int(sum(df_dsa_p10['Valor_Venda']))), xy = (-0.2, 0))
plt.title('Total de Vendas Por Categoria e Top 12 SubCategorias')
plt.show()

# %% [markdown]
# # Fim
